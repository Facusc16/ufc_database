# %% [markdown]
# # Requerimientos

# %% [markdown]
# ## Importar librerías

# %%
import pandas as pd
import mysql.connector
import to_db
import requests

# %% [markdown]
# ## Definir DataFrames

# %%
events = pd.read_csv("ufc_events.csv")
fighters = pd.read_csv("ufc_fighters.csv")
fights = pd.read_csv("ufc_fights.csv")

# %% [markdown]
# # Limpieza y manipulación de datos

# %% [markdown]
# ## Quitar datos duplicados o reduntantes

# %% [markdown]
# ### Events

# %%
events = events.drop_duplicates().reset_index(drop=True)

# %% [markdown]
# ### Fights

# %%
fights = fights.drop_duplicates().reset_index(drop=True)

# %% [markdown]
# ## Arreglar errores estructurales

# %% [markdown]
# ### Events

# %% [markdown]
# #### Cambiar tipos de datos

# %% [markdown]
# ##### Convertir a Datetime

# %%
events['date'] = pd.to_datetime(events['date'])

# %% [markdown]
# #### Eventos faltantes

# %%
events_clean = events['name'].str.strip().str.replace(r'\s+', ' ', regex=True)
fights_clean = fights['event'].dropna().str.strip().str.replace(r'\s+', ' ', regex=True)

missing_event = set(fights_clean) - set(events_clean)
missing_event
# Out:
# {'UFC Fight Night: Figueiredo vs. Benavidez 2',
#  'UFC Fight Night: Kattar vs. Ige',
#  'UFC Fight Night: Ngannou vs. Dos Santos'}

# %%
missing_events = {
    'events': [
        {'name': 'UFC Fight Night: Figueiredo vs. Benavidez 2',
         'date': '2020-07-18T21:00Z',
         'country': 'United Arab Emirates',
         'city': 'Abu Dhabi',
         'venue': 'Flash Forum'},
        {'name': 'UFC Fight Night: Kattar vs. Ige',
         'date': '2020-07-15T23:00Z',
         'country': 'United Arab Emirates',
         'city': 'Abu Dhabi',
         'venue': 'Flash Forum'},
        {'name': 'UFC Fight Night: Ngannou vs. Dos Santos',
         'date': '2019-06-29T22:00Z',
         'country': 'United States',
         'city': 'Minneapolis',
         'venue': 'Target Center'}
    ]
}

# %%
events = pd.concat([events, pd.DataFrame(missing_events['events'])], ignore_index=True)

# %%
len(fights.dropna(subset=['event']).groupby('event')) - len(events)
# Out:
# 0

# %% [markdown]
# ### Fighters

# %% [markdown]
# #### Cambiar tipos de datos

# %% [markdown]
# ##### Convertir a INT

# %%
int_fighters_cols = ['age', 'ko_tko_wins', 'decision_wins', 'submission_wins']
fighters[int_fighters_cols] = fighters[int_fighters_cols].astype("Int64")

# %% [markdown]
# ##### Convertir a Datetime

# %%
fighters['ufc_debut_date'] = fighters['ufc_debut_date'].apply(pd.to_datetime, errors='coerce')

# %% [markdown]
# #### Separar "professional_record" en columnas

# %%
# Obtener el índice de la columnas
pos = fighters.columns.get_loc('professional_record')

# Crear DataFrame con columnas respectivas para el record
record = fighters['professional_record'].str.extract(r'(\d+)-(\d+)-(\d+)')
record.columns = ['wins', 'losses', 'draws']
record = record.astype('Int64')

# Insertar nuevas columnas en el DataFrame sucecivamente a la columna base
for i, col in enumerate(record):
    fighters.insert(pos + i, col, record[col])

# Eliminar columnas base del DataFrame 
fighters = fighters.drop(columns=['professional_record'])

# %% [markdown]
# ### Fights

# %% [markdown]
# #### Cambiar tipos de datos

# %% [markdown]
# ##### Convertir a INT

# %%
int_fights_cols = ['possible_rounds', 'fight_order', 'round', 'total_strikes_attempted_red', 
                   'total_strikes_landed_red', 'significant_strikes_attempted_red', 
                   'significant_strikes_landed_red', 'knockdowns_red', 
                   'head_significant_strikes_red', 'body_significant_strikes_red', 
                   'leg_significant_strikes_red', 'distance_significant_strikes_red', 
                   'clinch_significant_strikes_red', 'ground_significant_strikes_red', 
                   'takedowns_attempted_red', 'takedowns_landed_red', 'submission_attempts_red', 
                   'reversals_red', 'total_strikes_attempted_blue', 'total_strikes_landed_blue',
                   'significant_strikes_attempted_blue', 'significant_strikes_landed_blue',
                   'knockdowns_blue', 'head_significant_strikes_blue',
                   'body_significant_strikes_blue', 'leg_significant_strikes_blue',
                   'distance_significant_strikes_blue', 'clinch_significant_strikes_blue',
                   'ground_significant_strikes_blue', 'takedowns_attempted_blue',
                   'takedowns_landed_blue', 'submission_attempts_blue', 'reversals_blue']

fights[int_fights_cols] = fights[int_fights_cols].astype('Int64')

# %% [markdown]
# ##### Convertir a Timedelta

# %%
time_fights_cols = ['time', 'clinch_control_time_red', 'ground_control_time_red',
                    'clinch_control_time_blue', 'ground_control_time_blue']

fights[time_fights_cols] = fights[time_fights_cols].apply(lambda col: pd.to_timedelta("00:" + col))

# %% [markdown]
# ##### Convertir a Bool

# %%
bool_fights_cols = ['fight_of_the_night', 'ko_of_the_night_red', 'submission_of_the_night_red', 
                    'performance_of_the_night_red', 'ko_of_the_night_blue', 
                    'submission_of_the_night_blue', 'performance_of_the_night_blue']

fights[bool_fights_cols] = fights[bool_fights_cols].astype("bool")

# %% [markdown]
# ## Manejar valores NaN

# %% [markdown]
# ### Events

# %%
events.isna().sum()
# Out:
# name       0
# date       0
# country    0
# city       0
# venue      0
# dtype: int64

# %% [markdown]
# ### Fighters

# %%
fighters.isna().sum()
# Out:
# name                  0
# nickname           1267
# place_of_birth      187
# age                 260
# height              315
# reach              1152
# leg_reach          1434
# fighting_style     2052
# ufc_debut_date        0
# wins                 40
# losses               40
# draws                40
# ko_tko_wins          49
# decision_wins        49
# submission_wins      49
# is_active             0
# dtype: int64

# %% [markdown]
# #### wins/losses/draws

# %%
# Obtener los nombres de los peleadores cuyo record sea NaN
wins_nan = fighters[fighters['wins'].isna()]['name']
losses_nan = fighters[fighters['losses'].isna()]['name']
draws_nan = fighters[fighters['draws'].isna()]['name']

# Verificar que los valores faltantes correspondan a los mismos peleadores en todos los casos
set(wins_nan) == set(losses_nan) == set(draws_nan)
# Out:
# True

# %%
fighters[fighters['wins'].isna()].sort_values(by='ufc_debut_date')
# Out:
#                              name              nickname   place_of_birth  \
# 1307      Asikeerbai Jinensibieke                   NaN  Xinjiang, China
# 1705                Dallas Marron            "El Tigre"              NaN
# 1047             Logan Greenhalgh                "Tank"              NaN
# 409                 Kitt Campbell                   NaN              NaN
# 302              Michael Bonnette            "No Mercy"              NaN
# 2730         Vineesh Subrahmanyan                "Vini"              NaN
# 130                Carrese Archer           "One Punch"              NaN
# 1716                Justin Martin                   NaN              NaN
# 1771               Sean Mcinerney             "Poopies"              NaN
# 1795             Dominik Melendez          "The Menace"              NaN
# 1843              Martin Mishtaku               "Booth"              NaN
# 2344               Keifer Roberts                "Keif"              NaN
# 1694               Jesse Mariotti           "Slap Papi"              NaN
# 2375                  Saul Rogers                   NaN    United States
# 2632                Michael Smith          "Slap Jesus"              NaN
# 2744                  Evan Sweesy      "Showtime Swees"              NaN
# 2762              Montrel Talbert                "Bone"              NaN
# 2788                   Testy Test               "Testy"              NaN
# 2800               Timothy Thomas         "The Gorilla"              NaN
# 1944           Przemyslaw Mysiala                   NaN              NaN
# 1689             William Marcario            "Patolino"           Brazil
# 1384                  Kerry Kasik                   NaN    United States
# 1408                 Casey Kenney                   NaN              NaN
# 239                  Cody Belisle           "Bodacious"              NaN
# 462                 Alberta Cerra                   NaN    United States
# 516                   Coltin Cole           "The Truth"              NaN
# 536                   Cory Corbin               "Hamma"              NaN
# 540               Jonathan Correa  "Puerto Rican Rambo"              NaN
# 550                    Davi Costa                   NaN              NaN
# 835                   Jair Farias                   NaN              NaN
# 857                 Test Fighter2                   NaN              NaN
# 947               Harrison Garcia              "Hitman"              NaN
# 1055               Garrett Grimes                   NaN              NaN
# 1195                Frank Holland            "The Tank"              NaN
# 1260                  Issa Isakov                   NaN              NaN
# 1265  Alvaro Ivan Lopez Rodrigues                   NaN           Mexico
# 1279               Jordan Jackson    "The Super Saiyan"              NaN
# 2874               Richie Vaculik                   NaN        Australia
# 1675                Bilyal Makhov                   NaN     USSR, Russia
# 2983               Dakota Weigher           "Iron Slap"              NaN
#
#        age  height  reach  leg_reach fighting_style ufc_debut_date  wins  \
# 1307    34     NaN    NaN        NaN            NaN     2022-06-10  <NA>
# 1705  <NA>     NaN    NaN        NaN            NaN     2024-02-09  <NA>
# 1047  <NA>     NaN    NaN        NaN            NaN     2024-06-28  <NA>
# 409     30     NaN    NaN        NaN            NaN     2025-05-23  <NA>
# 302     34     NaN    NaN        NaN            NaN     2025-12-08  <NA>
# 2730  <NA>     NaN    NaN        NaN            NaN     2025-12-08  <NA>
# 130     33    72.0   73.0        NaN            NaN     2025-12-09  <NA>
# 1716  <NA>     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 1771    36     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 1795  <NA>     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 1843    36     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 2344    30     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 1694    26     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 2375    33     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 2632    37    71.0   72.0        NaN            NaN     2025-12-09  <NA>
# 2744  <NA>     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 2762    30     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 2788  <NA>     NaN    NaN       34.0            NaN     2025-12-09  <NA>
# 2800    34     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 1944  <NA>     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 1689    31     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 1384  <NA>     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 1408  <NA>     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 239     30     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 462   <NA>     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 516     34     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 536     36     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 540   <NA>     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 550   <NA>     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 835   <NA>     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 857   <NA>     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 947   <NA>     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 1055    29     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 1195    34    69.0   70.0        NaN            NaN     2025-12-09  <NA>
# 1260  <NA>     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 1265  <NA>     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 1279    23     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 2874  <NA>     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 1675    35     NaN    NaN        NaN            NaN     2025-12-09  <NA>
# 2983    33     NaN    NaN        NaN            NaN     2025-12-09  <NA>
#
#       losses  draws  ko_tko_wins  decision_wins  submission_wins  is_active
# 1307    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 1705    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 1047    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 409     <NA>   <NA>         <NA>           <NA>             <NA>       True
# 302     <NA>   <NA>         <NA>           <NA>             <NA>       True
# 2730    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 130     <NA>   <NA>         <NA>           <NA>             <NA>       True
# 1716    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 1771    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 1795    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 1843    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 2344    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 1694    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 2375    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 2632    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 2744    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 2762    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 2788    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 2800    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 1944    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 1689    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 1384    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 1408    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 239     <NA>   <NA>         <NA>           <NA>             <NA>       True
# 462     <NA>   <NA>         <NA>           <NA>             <NA>       True
# 516     <NA>   <NA>         <NA>           <NA>             <NA>       True
# 536     <NA>   <NA>         <NA>           <NA>             <NA>       True
# 540     <NA>   <NA>         <NA>           <NA>             <NA>       True
# 550     <NA>   <NA>         <NA>           <NA>             <NA>       True
# 835     <NA>   <NA>         <NA>           <NA>             <NA>       True
# 857     <NA>   <NA>         <NA>           <NA>             <NA>       True
# 947     <NA>   <NA>         <NA>           <NA>             <NA>       True
# 1055    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 1195    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 1260    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 1265    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 1279    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 2874    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 1675    <NA>   <NA>         <NA>           <NA>             <NA>       True
# 2983    <NA>   <NA>         <NA>           <NA>             <NA>       True

# %% [markdown]
# #### ko_tko/decision/submission wins

# %%
# Obtener los nombres de los peleadores cuyas finalizaciones son Nan
ko_nan = fighters[fighters['ko_tko_wins'].isna()]['name']
decisions_nan = fighters[fighters['decision_wins'].isna()]['name']
submission_nan = fighters[fighters['submission_wins'].isna()]['name']

# Verificar que los valores faltantes correspondan a los mismos peleadores en todos los casos
set(ko_nan) == set(decisions_nan) == set(submission_nan)
# Out:
# True

# %%
fighters[fighters['ko_tko_wins'].isna()].sort_values(by='ufc_debut_date')
# Out:
#                              name              nickname  \
# 1257                  Enson Inoue                   NaN
# 323                Ebenezer Braga                   NaN
# 1307      Asikeerbai Jinensibieke                   NaN
# 1705                Dallas Marron            "El Tigre"
# 1047             Logan Greenhalgh                "Tank"
# 409                 Kitt Campbell                   NaN
# 302              Michael Bonnette            "No Mercy"
# 2730         Vineesh Subrahmanyan                "Vini"
# 1675                Bilyal Makhov                   NaN
# 1689             William Marcario            "Patolino"
# 1694               Jesse Mariotti           "Slap Papi"
# 1716                Justin Martin                   NaN
# 1771               Sean Mcinerney             "Poopies"
# 1795             Dominik Melendez          "The Menace"
# 2344               Keifer Roberts                "Keif"
# 1944           Przemyslaw Mysiala                   NaN
# 1567              Chi Lewis-Parry                   NaN
# 2375                  Saul Rogers                   NaN
# 2475                Sean Santella         "Shorty Rock"
# 2632                Michael Smith          "Slap Jesus"
# 2744                  Evan Sweesy      "Showtime Swees"
# 2762              Montrel Talbert                "Bone"
# 2788                   Testy Test               "Testy"
# 2800               Timothy Thomas         "The Gorilla"
# 1843              Martin Mishtaku               "Booth"
# 1468                 Jorgen Kruth     "The Last Viking"
# 61                 Amir Aliakbari                   NaN
# 1384                  Kerry Kasik                   NaN
# 130                Carrese Archer           "One Punch"
# 239                  Cody Belisle           "Bodacious"
# 462                 Alberta Cerra                   NaN
# 516                   Coltin Cole           "The Truth"
# 536                   Cory Corbin               "Hamma"
# 540               Jonathan Correa  "Puerto Rican Rambo"
# 550                    Davi Costa                   NaN
# 835                   Jair Farias                   NaN
# 853                   Timo Feucht                   NaN
# 857                 Test Fighter2                   NaN
# 871                  Isi Fitikefu                   NaN
# 907                  Artem Frolov                   NaN
# 947               Harrison Garcia              "Hitman"
# 1055               Garrett Grimes                   NaN
# 1195                Frank Holland            "The Tank"
# 1260                  Issa Isakov                   NaN
# 1265  Alvaro Ivan Lopez Rodrigues                   NaN
# 1279               Jordan Jackson    "The Super Saiyan"
# 2874               Richie Vaculik                   NaN
# 1408                 Casey Kenney                   NaN
# 2983               Dakota Weigher           "Iron Slap"
#
#                place_of_birth   age  height  reach  leg_reach fighting_style  \
# 1257            United States    56     0.0    NaN        NaN            NaN
# 323    Rio de Janeiro, Brazil    54     0.0    NaN        NaN            NaN
# 1307          Xinjiang, China    34     NaN    NaN        NaN            NaN
# 1705                      NaN  <NA>     NaN    NaN        NaN            NaN
# 1047                      NaN  <NA>     NaN    NaN        NaN            NaN
# 409                       NaN    30     NaN    NaN        NaN            NaN
# 302                       NaN    34     NaN    NaN        NaN            NaN
# 2730                      NaN  <NA>     NaN    NaN        NaN            NaN
# 1675             USSR, Russia    35     NaN    NaN        NaN            NaN
# 1689                   Brazil    31     NaN    NaN        NaN            NaN
# 1694                      NaN    26     NaN    NaN        NaN            NaN
# 1716                      NaN  <NA>     NaN    NaN        NaN            NaN
# 1771                      NaN    36     NaN    NaN        NaN            NaN
# 1795                      NaN  <NA>     NaN    NaN        NaN            NaN
# 2344                      NaN    30     NaN    NaN        NaN            NaN
# 1944                      NaN  <NA>     NaN    NaN        NaN            NaN
# 1567  Hitchin, United Kingdom    39     NaN    NaN        NaN            NaN
# 2375            United States    33     NaN    NaN        NaN            NaN
# 2475     Dover, United States    38    64.0    NaN        NaN            NaN
# 2632                      NaN    37    71.0   72.0        NaN            NaN
# 2744                      NaN  <NA>     NaN    NaN        NaN            NaN
# 2762                      NaN    30     NaN    NaN        NaN            NaN
# 2788                      NaN  <NA>     NaN    NaN       34.0            NaN
# 2800                      NaN    34     NaN    NaN        NaN            NaN
# 1843                      NaN    36     NaN    NaN        NaN            NaN
# 1468                   Sweden    49    74.0    NaN        NaN            NaN
# 61                        NaN    39     NaN    NaN        NaN            NaN
# 1384            United States  <NA>     NaN    NaN        NaN            NaN
# 130                       NaN    33    72.0   73.0        NaN            NaN
# 239                       NaN    30     NaN    NaN        NaN            NaN
# 462             United States  <NA>     NaN    NaN        NaN            NaN
# 516                       NaN    34     NaN    NaN        NaN            NaN
# 536                       NaN    36     NaN    NaN        NaN            NaN
# 540                       NaN  <NA>     NaN    NaN        NaN            NaN
# 550                       NaN  <NA>     NaN    NaN        NaN            NaN
# 835                       NaN  <NA>     NaN    NaN        NaN            NaN
# 853                       NaN    27     NaN    NaN        NaN            NaN
# 857                       NaN  <NA>     NaN    NaN        NaN            NaN
# 871               New Zealand    30     NaN    NaN        NaN            NaN
# 907                       NaN    31     NaN    NaN        NaN            NaN
# 947                       NaN  <NA>     NaN    NaN        NaN            NaN
# 1055                      NaN    29     NaN    NaN        NaN            NaN
# 1195                      NaN    34    69.0   70.0        NaN            NaN
# 1260                      NaN  <NA>     NaN    NaN        NaN            NaN
# 1265                   Mexico  <NA>     NaN    NaN        NaN            NaN
# 1279                      NaN    23     NaN    NaN        NaN            NaN
# 2874                Australia  <NA>     NaN    NaN        NaN            NaN
# 1408                      NaN  <NA>     NaN    NaN        NaN            NaN
# 2983                      NaN    33     NaN    NaN        NaN            NaN
#
#      ufc_debut_date  wins  losses  draws  ko_tko_wins  decision_wins  \
# 1257     1997-05-30     0       0      0         <NA>           <NA>
# 323      1998-10-16     0       0      0         <NA>           <NA>
# 1307     2022-06-10  <NA>    <NA>   <NA>         <NA>           <NA>
# 1705     2024-02-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 1047     2024-06-28  <NA>    <NA>   <NA>         <NA>           <NA>
# 409      2025-05-23  <NA>    <NA>   <NA>         <NA>           <NA>
# 302      2025-12-08  <NA>    <NA>   <NA>         <NA>           <NA>
# 2730     2025-12-08  <NA>    <NA>   <NA>         <NA>           <NA>
# 1675     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 1689     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 1694     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 1716     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 1771     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 1795     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 2344     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 1944     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 1567     2025-12-09     0       0      0         <NA>           <NA>
# 2375     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 2475     2025-12-09     0       0      0         <NA>           <NA>
# 2632     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 2744     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 2762     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 2788     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 2800     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 1843     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 1468     2025-12-09     5       0      0         <NA>           <NA>
# 61       2025-12-09     0       0      0         <NA>           <NA>
# 1384     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 130      2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 239      2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 462      2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 516      2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 536      2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 540      2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 550      2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 835      2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 853      2025-12-09     0       0      0         <NA>           <NA>
# 857      2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 871      2025-12-09     0       0      0         <NA>           <NA>
# 907      2025-12-09     0       0      0         <NA>           <NA>
# 947      2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 1055     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 1195     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 1260     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 1265     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 1279     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 2874     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 1408     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
# 2983     2025-12-09  <NA>    <NA>   <NA>         <NA>           <NA>
#
#       submission_wins  is_active
# 1257             <NA>       True
# 323              <NA>       True
# 1307             <NA>       True
# 1705             <NA>       True
# 1047             <NA>       True
# 409              <NA>       True
# 302              <NA>       True
# 2730             <NA>       True
# 1675             <NA>       True
# 1689             <NA>       True
# 1694             <NA>       True
# 1716             <NA>       True
# 1771             <NA>       True
# 1795             <NA>       True
# 2344             <NA>       True
# 1944             <NA>       True
# 1567             <NA>       True
# 2375             <NA>       True
# 2475             <NA>       True
# 2632             <NA>       True
# 2744             <NA>       True
# 2762             <NA>       True
# 2788             <NA>       True
# 2800             <NA>       True
# 1843             <NA>       True
# 1468             <NA>       True
# 61               <NA>       True
# 1384             <NA>       True
# 130              <NA>       True
# 239              <NA>       True
# 462              <NA>       True
# 516              <NA>       True
# 536              <NA>       True
# 540              <NA>       True
# 550              <NA>       True
# 835              <NA>       True
# 853              <NA>       True
# 857              <NA>       True
# 871              <NA>       True
# 907              <NA>       True
# 947              <NA>       True
# 1055             <NA>       True
# 1195             <NA>       True
# 1260             <NA>       True
# 1265             <NA>       True
# 1279             <NA>       True
# 2874             <NA>       True
# 1408             <NA>       True
# 2983             <NA>       True

# %% [markdown]
# ### Fights

# %%
fights.isna().sum()
# Out:
# event                                    0
# weight_class                            75
# weight                                 199
# catch_weight_lbs                      8392
# accolades                                0
# possible_rounds                          0
# card_segment                           616
# fight_order                              0
# status                                   0
# winner                                 149
# outcome                               8318
# round                                    0
# time                                     0
# method                                   0
# ending_submission                     6811
# fight_of_the_night                       0
# referee                                  0
# red_corner                               0
# total_strikes_attempted_red             21
# total_strikes_landed_red                21
# significant_strikes_attempted_red       21
# significant_strikes_landed_red          21
# knockdowns_red                          21
# head_significant_strikes_red            21
# body_significant_strikes_red            21
# leg_significant_strikes_red             21
# distance_significant_strikes_red        21
# clinch_significant_strikes_red          21
# ground_significant_strikes_red          21
# takedowns_attempted_red                 21
# takedowns_landed_red                    21
# submission_attempts_red                 21
# reversals_red                           21
# clinch_control_time_red                203
# ground_control_time_red                203
# ko_of_the_night_red                      0
# submission_of_the_night_red              0
# performance_of_the_night_red             0
# blue_corner                              0
# total_strikes_attempted_blue            21
# total_strikes_landed_blue               21
# significant_strikes_attempted_blue      21
# significant_strikes_landed_blue         21
# knockdowns_blue                         21
# head_significant_strikes_blue           21
# body_significant_strikes_blue           21
# leg_significant_strikes_blue            21
# distance_significant_strikes_blue       21
# clinch_significant_strikes_blue         21
# ground_significant_strikes_blue         21
# takedowns_attempted_blue                21
# takedowns_landed_blue                   21
# submission_attempts_blue                21
# reversals_blue                          21
# clinch_control_time_blue               203
# ground_control_time_blue               203
# ko_of_the_night_blue                     0
# submission_of_the_night_blue             0
# performance_of_the_night_blue            0
# dtype: int64

# %% [markdown]
# #### Event

# %%
fights = fights.drop(8444).reset_index(drop=True)

# %% [markdown]
# #### Weight_class/Catch_weight_lbs

# %% [markdown]
# Se justifican los valores NaN ya que fueron peleas en peso pactado

# %%
fights[fights['weight_class'].isna()]['catch_weight_lbs'].isna().sum()
# Out:
# 0

# %% [markdown]
# Se justifican los valores NaN, ya que corresponden a peleas correspondientes a una categoría específica

# %%
fights[fights['catch_weight_lbs'].isna()]['weight_class'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Weight

# %% [markdown]
# Se justifican los valores NaN, ya que fueron peleas de peso libre

# %%
fights[(fights['weight'].isna()) & (fights['weight_class'].notna())]['weight_class'].unique()
# Out:
# array(['Open Weight'], dtype=object)

# %% [markdown]
# #### Card_segment

# %% [markdown]
# No es clara la transición entre eventos sin división en su cartelera y los primeros eventos con preliminares. Hay casos de peleas que cumplian un rol parecido, pero no hay información precisa sobre eso y la base de datos de la UFC no las clasifica en sus archivos JSON, dejandolas como None. Por lo que no asignaré valores solo por suposición.

# %% [markdown]
# #### Winner/Outcome

# %% [markdown]
# Se justifican los valores NaN, ya que las peleas no pudieron terminar o terminaron en empate

# %%
fights[fights['winner'].isna()]['outcome'].unique()
# Out:
# array(['Draw', 'No Contest', nan], dtype=object)

# %% [markdown]
# Se justifican los valores NaN, ya que las peleas efectivamente tuvieron un ganador

# %%
fights[fights['outcome'].isna()]['winner'].isna().sum()
# Out:
# 5

# %% [markdown]
# #### Round/Time/Method

# %%
fights[fights['round'].isna()][['event', 'red_corner', 'blue_corner', 'status', 'round', 'time', 'method']]
# Out:
#                                         event       red_corner  \
# 1049   UFC Fight Night: Dariush vs. Tsarukyan       Dan Hooker
# 1383          UFC Fight Night: Song vs. Simon   Brian Kelleher
# 2784  UFC Fight Night: Brunson vs. Shahbazyan    Kevin Holland
# 3290                UFC 239: Jones vs. Santos  Francis Ngannou
# 3645               UFC 230: Cormier vs. Lewis   Brian Kelleher
#
#             blue_corner    status  round time method
# 1049         King Green  Canceled   <NA>  NaT    NaN
# 1383     Journey Newson  Canceled   <NA>  NaT    NaN
# 2784       Trevin Giles  Canceled   <NA>  NaT    NaN
# 3290  Junior Dos Santos  Canceled   <NA>  NaT    NaN
# 3645     Montel Jackson  Canceled   <NA>  NaT    NaN

# %%
# Eliminar peleas canceladas
fights = fights.drop(fights[fights['round'].isna()].index).reset_index(drop=True)

# %% [markdown]
# #### Ending submission

# %% [markdown]
# Se justifican los valores NaN, ya que dichas peleas no terminaron por sumisión y no cuentan con un valor con el que rellenar esa columna

# %%
len(fights[fights['method'] != 'Submission']) - len(fights[fights['ending_submission'].isna()])
# Out:
# 8

# %% [markdown]
# 8 filas fueron encontradas donde el valor de la columna 'method' es distinto a 'submission', eso se debe a que dichas peleas terminaro por sumisión, pero luego fueron declaradas No Contest y el método cambiado a 'Overturned', sin eliminar el nombre de la sumisión.

# %%
len(fights[(fights['outcome'] == 'No Contest') & (fights['ending_submission'].notna())])
# Out:
# 8

# %% [markdown]
# #### Red/Blue stats

# %% [markdown]
# No se encuentran disponibles las estadísticas de dichas peleas, por lo que sus valores NaN serán dejados tal cual

# %%
stats = fights[fights['total_strikes_attempted_red'].isna()]

# %%
over = fights[fights['status'] == 'Over']

# %%
set(stats) == set(over)
# Out:
# True

# %%
red_clinch = fights[fights['clinch_control_time_red'].isna()]
red_ground = fights[fights['ground_control_time_red'].isna()]
blue_clinch = fights[fights['clinch_control_time_blue'].isna()]
blue_ground = fights[fights['ground_control_time_blue'].isna()]

set(red_clinch) == set(blue_clinch) == set(red_ground) == set(blue_ground)
# Out:
# True

# %% [markdown]
# # Crear base de datos

# %%
# Establecer conexión para crear base de datos
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password=""
)   

cursor = conn.cursor()

cursor.execute("CREATE DATABASE IF NOT EXISTS ufc_db")

cursor.close()
conn.close()

# %% [markdown]
# ## Configurariones

# %%
# Establecer conexión para crear tablas e insertar filas
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="ufc_db"
)
cursor = conn.cursor()

# %%
# Diccionario de equivalencias de tipos
mysql_types = {
    "object": "VARCHAR(255)",
    "float64": "FLOAT",
    "int64": "INT",
    "Int64": "INT",
    "bool": "TINYINT(1)",
    "datetime64[ns]": "DATETIME",
    "datetime64[ns, UTC]": "DATETIME",
    "timedelta64[ns]": "TIME"
}

# %% [markdown]
# ## Crear tablas independientes

# %% [markdown]
# ### Fighters

# %%
fighters_table = {
    'name': 'fighters',
    'id': 'fighter_id',
    'fk': '',
    'pk': 'fighter_id'
}

# %%
to_db.create_table(fighters_table, fighters, mysql_types, cursor)
new_fighters = to_db.get_new_rows(fighters_table['name'], fighters, cursor)
to_db.insert_into(fighters_table['name'], new_fighters, cursor, conn)
# Out:
# Tabla vacía, todas las filas podrán ser insertadas

# %% [markdown]
# ### Submissions

# %%
submissions = fights[['ending_submission']].dropna().drop_duplicates()
submissions.rename(columns={'ending_submission': 'name'}, inplace=True)

submissions_table = {
    'name': 'submissions',
    'id': 'submission_id',
    'fk': '',
    'pk': 'submission_id'
}

# %%
to_db.create_table(submissions_table, submissions, mysql_types, cursor)
new_submissions = to_db.get_new_rows(submissions_table['name'], submissions, cursor)
to_db.insert_into(submissions_table['name'], new_submissions, cursor, conn)
# Out:
# Tabla vacía, todas las filas podrán ser insertadas

# %% [markdown]
# ### Weight Classes

# %%
weight_classes = fights[fights['weight_class'].notna()][['weight_class', 'weight']].drop_duplicates().sort_values(by='weight')
weight_classes.rename(columns={'weight_class': 'name', 'weight': 'weight_range'}, inplace=True)

weight_classes_table = {
    'name': 'weight_classes',
    'id': 'weight_class_id',
    'fk': '',
    'pk': 'weight_class_id'
}

# %%
to_db.create_table(weight_classes_table, weight_classes, mysql_types, cursor)
to_db.insert_into(weight_classes_table['name'], weight_classes, cursor, conn)

# %% [markdown]
# ### Referees

# %%
referees = fights[['referee']]
referees.rename(columns={'referee': 'name'}, inplace=True)

referees_table = {
    'name': 'referees',
    'id': 'referee_id',
    'fk': '',
    'pk': 'referee_id'
}
# Out:
# C:\Users\facun\AppData\Local\Temp\ipykernel_16916\1014917402.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   referees.rename(columns={'referee': 'name'}, inplace=True)

# %%
to_db.create_table(referees_table, referees, mysql_types, cursor)
new_referees = to_db.get_new_rows(referees_table['name'], referees, cursor)
to_db.insert_into(referees_table['name'], new_referees, cursor, conn)
# Out:
# Tabla vacía, todas las filas podrán ser insertadas

# %% [markdown]
# ### Venues

# %%
venues = events[['venue', 'country', 'state', 'city']].drop_duplicates()
venues.rename(columns={'venue': 'name'}, inplace=True)

venues_table = {
    'name': 'venues',
    'id': 'venue_id',
    'fk': '',
    'pk': 'venue_id'
}

# %%
to_db.create_table(venues_table, venues, mysql_types, cursor)
new_venues = to_db.get_new_rows(venues_table['name'], venues, cursor)
to_db.insert_into(venues_table['name'], new_venues, cursor, conn)
# Out:
# Tabla vacía, todas las filas podrán ser insertadas

# %% [markdown]
# ## Crear tablas dependientes

# %% [markdown]
# ### Events

# %% [markdown]
# #### Cambias nombres de columnas en events y reemplazar sus valores por IDs

# %%
# Renombrar llaves foráneas
events.rename(columns={'venue': 'venue_id'}, inplace=True)

# %%
# Reemplazar nombre del venue por su ID
events['venue_id'] = events['venue_id'].apply(lambda x: to_db.get_id('venue_id', 'venues', 'name', x, cursor))

# %% [markdown]
# #### Crear tabla

# %%
to_events = events[['name', 'date', 'venue_id']]
events_table = {
    'name': 'events',
    'id': 'event_id',
    'fk': [('venue_id', 'venues', 'venue_id')],
    'pk': 'event_id'
}

# %%
to_db.create_table(events_table, to_events, mysql_types, cursor)
new_events = to_db.get_new_rows(events_table['name'], to_events, cursor)
to_db.insert_into(events_table['name'], new_events, cursor, conn)
# Out:
# Tabla vacía, todas las filas podrán ser insertadas

# %% [markdown]
# ### Fights

# %% [markdown]
# #### Cambiar nombres de columnas en fights y reemplazar sus valores por IDs

# %%
# Renombrar llaves foráneas
fights.rename(columns={
    'event': 'event_id', 
    'weight_class':'weight_class_id',
    'winner': 'winner_id',
    'ending_submission': 'submission_id',
    'referee': 'referee_id',
    'red_corner': 'red_corner_id', 
    'blue_corner': 'blue_corner_id'
    }, inplace=True)

# %%
# Reemplazar nombre del evento por su ID
fights['event_id'] = fights['event_id'].apply(lambda x: to_db.get_id('event_id', 'events', 'name', x, cursor))

# %%
# Reemplazar el nombre de la categoría por su ID
fights['weight_class_id'] = fights['weight_class_id'].apply(lambda x: to_db.get_id('weight_class_id',  'weight_classes', 'name', x, cursor))

# %%
# Reemplazar el nombre del ganador por su ID
fights['winner_id'] = fights['winner_id'].apply(lambda x: to_db.get_id('fighter_id', 'fighters', 'name', x, cursor))

# %%
# Reemplazar el nombre de la sumisión por su ID
fights['submission_id'] = fights['submission_id'].apply(lambda x: to_db.get_id('submission_id', 'submissions', 'name', x, cursor))

# %%
# Reemplazar el nombre del referee por su ID
fights['referee_id'] = fights['referee_id'].apply(lambda x: to_db.get_id('referee_id', 'referees', 'name', x, cursor))

# %%
# Reemplazar esquina roja por su ID
fights['red_corner_id'] = fights['red_corner_id'].apply(lambda x: to_db.get_id('fighter_id', 'fighters', 'name', x, cursor))

# %%
# Reemplazar esquina azul por su ID
fights['blue_corner_id'] = fights['blue_corner_id'].apply(lambda x: to_db.get_id('fighter_id', 'fighters', 'name', x, cursor))

# %%
# Cambiar tipo de dato a Int64
cols = ['event_id', 'weight_class_id', 'winner_id', 'submission_id', 'referee_id', 'red_corner_id', 'blue_corner_id']
fights[cols] = fights[cols].astype('Int64')

# %% [markdown]
# #### Crear tabla

# %%
to_fights = fights.drop(columns=['weight'])
fights_table = {
    'name': 'fights',
    'id': 'fight_id',
    'fk': [('event_id', 'events', 'event_id'),
           ('weight_class_id', 'weight_classes', 'weight_class_id'),
           ('winner_id', 'fighters', 'fighter_id'),
           ('submission_id', 'submissions', 'submission_id'),
           ('referee_id', 'referees', 'referee_id'),
           ('red_corner_id', 'fighters', 'fighter_id'),
           ('blue_corner_id', 'fighters', 'fighter_id')],
    'pk': 'fight_id'
}

# %%
to_db.create_table(fights_table, to_fights, mysql_types, cursor)
new_fights = to_db.get_new_rows(fights_table['name'], to_fights, cursor)
to_db.insert_into(fights_table['name'], new_fights, cursor, conn)
# Out:
# Tabla vacía, todas las filas podrán ser insertadas
